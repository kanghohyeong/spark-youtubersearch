# %% [markdown]
# # 감성분석

# %%
# 영화 리뷰 데이터 불러오기
import pandas as pd

review_df = pd.read_csv('./movie_text_data/ratings.txt', header=0, sep="\t", quoting=3)
review_df.head(3)
# Out:
#         id                                           document  label
# 0  8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1  8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2  4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1

# %%
# 전처리
import re


review_df['document'] = review_df['document'].apply(lambda x : re.sub(pattern="[^ㄱ-ㅎ 가-힣 a-z A-Z]", repl=" ", string=str(x)))

review_df.head(10)
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로  외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는  부터 뉴까지 버릴께 하나도 없음   최고       1
# 3   9251303  와   연기가 진짜 개쩔구나   지루할거라고 생각했는데 몰입해서 봤다   그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화       1
# 5   2190435                      사랑을 해본사람이라면 처음부터 끝까지 웃을수 있는영화      1
# 6   9279041                                   완전 감동입니다 다시봐도 감동      1
# 7   7865729                        개들의 전쟁  나오나요  나오면  빠로 보고 싶음      1
# 8   7477618                                                  굿      1
# 9   9250537                                     바보가 아니라 병 쉰 인듯      1

# %%
#test - train set 나누기

from sklearn.model_selection import train_test_split

class_df = review_df['label']
feature_df = review_df.drop(['id', 'label'], axis=1, inplace=False)

X_train, X_test, y_train, y_test = train_test_split(feature_df, class_df, test_size=0.3, random_state=156)

X_train.shape, X_test.shape
# Out:
# ((140000, 1), (60000, 1))

# %%
# 로지스틱 회귀 + CountVectorize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

pipeline = Pipeline([
    ('cnt_vect', CountVectorizer(ngram_range=(1,2))),
    ('lr_clf',LogisticRegression(C=10))

])

pipeline.fit(X_train['document'], y_train)
pred = pipeline.predict(X_test['document'])
pred_probs = pipeline.predict_proba(X_test['document'])[:,1]

print('예측 정확도는 {0:.4f}, ROC_AUC는 {1:.4f}'.format(accuracy_score(y_test, pred), roc_auc_score(y_test, pred_probs)))

cnt = 0
for review in X_test['document']:
    if pred[cnt] == 1:
        sentiment = 'positive'
    else:
        sentiment = 'negative'

    cnt += 1
    if cnt == 100:
        break

    print('댓글 :{0} 는 {1}로 예상됩니다'.format(review, sentiment))
# Out:
# 예측 정확도는 0.8116, ROC_AUC는 0.9028
# 댓글 :이름 함부러 짓는거 아니다 는 negative로 예상됩니다
# 댓글 : 점도 아깝다 쓰레기같은 영화 는 negative로 예상됩니다
# 댓글 :고어물론 최고다   기발한연출력   맘에들었음    는 positive로 예상됩니다
# 댓글 :이건 뭐 무섭지도 않고 는 negative로 예상됩니다
# 댓글 :다시는 중국이랑 같이 접목하지마라    쪽팔림 진심    중국을데려다가 이렇게밖에못써먹다니    는 negative로 예상됩니다
# 댓글 :꼴통 배우의 무작정 때려 부수고 아작내기  는 positive로 예상됩니다
# 댓글 :역시 판타지는 너무 잼있어 반지팬으로써   점 는 positive로 예상됩니다
# 댓글 :왜 평점이 이렇지     는 positive로 예상됩니다
# 댓글 :추억의 영화 는 positive로 예상됩니다
# 댓글 :배우에게 너무 의지하여 오히려 긴장감이 떨어지는 는 negative로 예상됩니다
# 댓글 :아  참내 볼일보고 안딱고 나온기분 현실성이 떨어지잔아 쌍팔년도에나 먹혔을법한 스토리였 는 negative로 예상됩니다
# 댓글 :월리스와 그루밋때부터 팬이여서   시리즈라 생각해 보았으나 난 이 스토리를 즐기기엔 너무 늙어버렸다  명절날 조카가 틀어놓으면 전부치며 볼듯  성인들이 볼 극장용 무비는 아님 는 negative로 예상됩니다
# 댓글 :혜진양  예전부터 팬으로서 다소 실망    는 negative로 예상됩니다
# 댓글 :음  우리 사랑이 때문에   는 positive로 예상됩니다
# 댓글 :극이 진행될수록 포스터에서 풍기는 일말의 기대감 흥미 을 무참히 날려버려주는 센스 는 negative로 예상됩니다
# 댓글 :글세 이건머 별로 무섭지도 않고 스토리도 영     몰입도도 별로인거같고 근데 왜이렇게 점수가 높은겨     는 negative로 예상됩니다
# 댓글 :어릴 적 꿈만 같았던 영화  아직도 교신 멜로디가 또렷이 생각난다  는 positive로 예상됩니다
# 댓글 :영화관에 내친구 둘이랑 나랑 진도나가려는 커플 이랑  명있었다   는 negative로 예상됩니다
# 댓글 :영화는 그저 그랬지만 김혜수의 압도적인 연기가 극을 이끌어가고 또 살림  뻔한 이야기의 느와르물이 독특하게 된건 차이나타운의 비주얼도 신인배우들의 연기도 아니고 오직 김혜수의 연기 때문에    는 negative로 예상됩니다
# 댓글 :그냥 시간떄우기용으로 봣는데  정말 너무너무 추천하고싶어요  정말 재밋어요    로코물의 정석을 보여주는듯 ㅎ 이영화를 통해서 불어의 매력도 함꼐 빠진듯해요 ㅎㅎㅎ 는 positive로 예상됩니다
# 댓글 :갑작스러운 라스트씬에 흠칫 는 negative로 예상됩니다
# 댓글 :다시 보니까 괜찮다 봐줄만 하다  는 positive로 예상됩니다
# 댓글 :감독은 관객을 상대로 게임을 하는것이다 는 negative로 예상됩니다
# 댓글 :cg다시보고싶다 는 negative로 예상됩니다
# 댓글 :결말이 막장을 달린다 는 negative로 예상됩니다
# 댓글 :전우 따위보다 훨 좋다  그 많은 돈  다 소지섭 몸값이지 ㅋㅋㅋ 는 positive로 예상됩니다
# 댓글 :공포를 가장한 코미디  주인공은 무지 심각하지만   구지성 출연으로 관심이 갖는 데 플롯은 괜찮았지만 전개가 너무 단순하고 느리다  는 negative로 예상됩니다
# 댓글 :최고  무스존재감대박이다진짜    는 positive로 예상됩니다
# 댓글 :보면서 울기도 했습니다  는 positive로 예상됩니다
# 댓글 :이 영화를 보고 느낀 것이라고는  나는 예술과 친하지 않구나  정도입니다  는 positive로 예상됩니다
# 댓글 :케빈때문에 봤지만  누구나 공감할수 있는 그런 얘기 는 positive로 예상됩니다
# 댓글 :별점도 아깝다 말도 안되는 영화 킬링타임용으로도 아까울정도    는 negative로 예상됩니다
# 댓글 :별하나도 아깝네 맹꽁치 이후로 안봄 는 negative로 예상됩니다
# 댓글 :중간 고고싱 는 negative로 예상됩니다
# 댓글 :내인생 최고의 영화    내가 본 이별 중 가장 슬프고 허무하기 짝이없다  는 positive로 예상됩니다
# 댓글 :볼만하네 는 positive로 예상됩니다
# 댓글 :완전 신기합니다요   고래 눈이 그렇게 깊은 줄 몰랐네용 는 positive로 예상됩니다
# 댓글 :유니크 는 positive로 예상됩니다
# 댓글 :더빙으로 보니깐 재밋네ㅋㅋㅋㅋ 꿀잼ㅋㅋㅋ kbs 명화극장 성우 및 출연진님들 감사해요  정말 재밋게 봤슴다ㅋ 는 positive로 예상됩니다
# 댓글 :제 가슴에 영원히 남을 영화 오래전이지만 종소리가 귀에 선하네요 는 positive로 예상됩니다
# 댓글 :토해 는 negative로 예상됩니다
# 댓글 :전자기유도법칙 ㅋㅋㅋ중 고 때 배우는 기본상식을 바탕으로 만든영화 CG ㅋㅋㅋ답도없다 ㄹㅇ 그림판으로 만든줄  점줄려다가 여주가 이쁘니깐  점줌 는 negative로 예상됩니다
# 댓글 :이게 락프로그램이냐 진심순위보다가 리모콘던질뻔  롹스코진심꼴뵈기실타   그리고 관중들좀 힙합좀 아는 사람 선별해서 뽑아요 뭔시스템이 일케구려  비아이가 떨어졌다는자체가 에바쎄바쓰레빠다이놈들아 는 positive로 예상됩니다
# 댓글 :정말정말정말정말 좋은 영화 내생애 처음으로 평점을 주고싶게 만든 영화 는 negative로 예상됩니다
# 댓글 :재능없는 감독이란 전혀 듣지 않는 마취약과 같다 한마디로 수술중 사용하면 즉사  는 negative로 예상됩니다
# 댓글 :ㅎㅎ 너무 재밌어 이거ㅋ 는 positive로 예상됩니다
# 댓글 :이영화 보시구 섹스만 생각 나신다면 영화잘못보시는거임       는 positive로 예상됩니다
# 댓글 :이런게 헐리우드 작품이라니 는 positive로 예상됩니다
# 댓글 :굿   굿   굿    는 negative로 예상됩니다
# 댓글 :야하지도 재미도 없는 영화 는 negative로 예상됩니다
# 댓글 :어디서 월e를 뛰어넘는 귀여움 이라는걸 봤는데 전혀    화면도 너무 지저분하게 움직이고 구성도 스토리도 별로  그냥 뛰어다는것밖에 없음  영화의    는 뛰어다님  이런 나쁜평 잘 안남기는데 많이 실망함   는 negative로 예상됩니다
# 댓글 :아름다운 영화  이은주가 참 사랑스럽게 나온다 새삼 그녀가 그리워진다 는 positive로 예상됩니다
# 댓글 :후기보고 할거없어서 봤는데 마지막 쯤에 슬펏음  근데 마지막씬은 없는게 나을듯 머리스타일이랑 메이크업이맘에 안들긴 했지만   그리고남자주인공은 귀엽긴한데 연기력이 좀  암튼 볼만하네야 여자 가슴수술 안한게 가장 좋았음 는 positive로 예상됩니다
# 댓글 :요즘 정말 아이들과 극장가서 볼만한것이 없었는데 이렇게 윈드랜드가 딱    개봉해서 보니 너무너무 좋아해요 는 positive로 예상됩니다
# 댓글 :존나 재미 없는 영화다 ㅇㅇ 는 negative로 예상됩니다
# 댓글 :이게   점받을 영화인지는 모르겠지만 내가 진지하게 본 영화로는 처음이기에  는 positive로 예상됩니다
# 댓글 :오늘 숨바꼭질 보고나니 이 영화가 생각낫음 원래 스릴러는 거의안봄 숨바꼭질보다 이 영화가 더 탄탄하다 는 positive로 예상됩니다
# 댓글 : 점도아깝네  드럽게재미없음  는 negative로 예상됩니다
# 댓글 :뒤쳐진 스타일에 개연성 없는 구조의 표본 는 negative로 예상됩니다
# 댓글 :빈틈없는 사극  관상다루는 영화는 헐리우드에서도 많이 못본것같은데 ㅎㅎ 는 positive로 예상됩니다
# 댓글 :진짜 내가사람들이랑관범이다른건가  친구 명이랑영화관봐서 봤는데 다너무어이가없어서 웃다만왔는데 는 positive로 예상됩니다
# 댓글 :재미없다  지루한내용 는 negative로 예상됩니다
# 댓글 :겨울 맥주 바다 엉망인삶 엉망인청춘 엉망인집들이 그래도웃을수있다 오늘을살기에  는 negative로 예상됩니다
# 댓글 :감독이 꼴리는대로 멋대로 찍은 듯  따라준 배우들이 불쌍하다  는 negative로 예상됩니다
# 댓글 :노력하는사람은 타고난사람을 이길수없다는 현실을 보여주는 프로  는 positive로 예상됩니다
# 댓글 :정말 소름끼치는 영화다    는 positive로 예상됩니다
# 댓글 :정말 재미있게 본 영화 는 positive로 예상됩니다
# 댓글 :이건 영화가 아니라 다큐다  는 negative로 예상됩니다
# 댓글 :목소리예쁘다 그런거아무필요없다 아니 아직 연기란걸배워보지도못한것들을상업영화에출연시킨다는건 성우란게 얼굴만알려지면 그게끝이란거냐  는 negative로 예상됩니다
# 댓글 :연기력이 검증되지 않은 배우는 작품의 몰입도를 떨어뜨린다   는 negative로 예상됩니다
# 댓글 :이런에로영화가있다니  무삭제로봤는데  완전헐이었다      는 negative로 예상됩니다
# 댓글 :진짜  편 감독 바뀌고 개망햇다   배우들만 화려하지 캐릭터들도  편이 훨씬 매력있음 감독 왜바꾼거냐 나한테는 지아이조는  편뿐임 는 negative로 예상됩니다
# 댓글 :내가 공포영화를 눈 안가리고 다 본건 이게 처음  그 정도로 안무섭다  는 negative로 예상됩니다
# 댓글 :초반에는 날뛰는 스킨헤드들의 짜릿한 반항기인줄 알았는데 무거운주제로 다시한번 더 생각해보게하는 영화 는 positive로 예상됩니다
# 댓글 :신은경 접대부연기는 좀 아닌듯 오인혜 그림은 참좋은듯  신은경 화이팅  는 negative로 예상됩니다

# %%
# 로지스틱 회귀 + TfidfVectorize

pipeline = Pipeline([
    ('tfidf_vect', TfidfVectorizer(ngram_range=(1,2))),
    ('lr_clf',LogisticRegression(C=10))

])

pipeline.fit(X_train['document'], y_train)
pred = pipeline.predict(X_test['document'])
pred_probs = pipeline.predict_proba(X_test['document'])[:,1]

print('예측 정확도는 {0:.4f}, ROC_AUC는 {1:.4f}'.format(accuracy_score(y_test, pred), roc_auc_score(y_test, pred_probs)))
# Out:
# 예측 정확도는 0.8150, ROC_AUC는 0.9054

# %%
# 유튜브 댓글 데이터 불러오기 유튜브 댓글로 예측해보기

import re


with open('./crawling_result_text/gamst_comments.txt', mode='rt', encoding='utf-8') as f:
    strings = f.read()

strings = re.sub(pattern='[^ㄱ-ㅎ 가-힣 a-z A-Z \n]', repl='', string=strings)
comment_list = strings.split('\n')

pred_comment = pipeline.predict(comment_list)
pred_probs_score = pipeline.predict_proba(comment_list)[:,1]


sentiment_result = []

cnt = 0
for comment in comment_list:
    if pred_comment[cnt] == 1:
        sentiment = 'positive'
    else:
        sentiment = 'negative'

    pred_score = pred_probs_score[cnt]

    cnt += 1

    print('[{0}] 는 ({2:.4f}) 확률로 {1}로 예상됩니다'.format(comment, sentiment, pred_score))
    sentiment_result.append('[{0}] 는 ({2:.4f}) 확률로 {1}로 예상됩니다'.format(comment, sentiment, pred_score))


with open('./crawling_result_text/comment_sentiment_LR_Tfidf.txt', mode='wt', encoding='utf-8') as f:
    f.write("\n".join(sentiment_result))
# Out:
# [영상 좋아요댓글 한번씩 부탁드립니다] 는 (0.7770) 확률로 positive로 예상됩니다
# [He is JJASTHIS] 는 (0.7166) 확률로 positive로 예상됩니다
# [HE IS NOT CHANGMO] 는 (0.8046) 확률로 positive로 예상됩니다
# [HE IS TALMO] 는 (0.7166) 확률로 positive로 예상됩니다
# [He is Talmoalto] 는 (0.7166) 확률로 positive로 예상됩니다
# [Bring rap JJASTHIS] 는 (0.5106) 확률로 positive로 예상됩니다
# [ He Is gamshebellom] 는 (0.7166) 확률로 positive로 예상됩니다
# [He is CODE GAMST] 는 (0.7587) 확률로 positive로 예상됩니다
# [THISISZZASTHIS] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 여긴 진짜 개잘했네 ㅋㅋㅋㅋ] 는 (0.8237) 확률로 positive로 예상됩니다
# [ he is punchline king] 는 (0.7881) 확률로 positive로 예상됩니다
# [보여줬지] 는 (0.4654) 확률로 negative로 예상됩니다
# [yo] 는 (0.2447) 확률로 negative로 예상됩니다
# [shut the fxxk a man] 는 (0.7048) 확률로 positive로 예상됩니다
# [ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [느슨해진 한국힙합에 긴장감을 주는것 같다] 는 (0.6900) 확률로 positive로 예상됩니다
# [  우결단의 인생 감스트] 는 (0.9299) 확률로 positive로 예상됩니다
# [ 여기서부터 ㅈㄴ노래 좋음] 는 (0.9812) 확률로 positive로 예상됩니다
# [ 개 중독된다 그냥 짜쓰디스 레게노] 는 (0.1906) 확률로 negative로 예상됩니다
# [  지렸다 ] 는 (0.5210) 확률로 positive로 예상됩니다
# [He is SMTM  WINNER] 는 (0.7166) 확률로 positive로 예상됩니다
# [  박자 맞는거 소름이누ㄷㄷ] 는 (0.2097) 확률로 negative로 예상됩니다
# [아니 프리스타일인데 랩을 이렇게 잘한다고ㅋㅋㅋㅋㅋ 그냥 말하는 것보다 더 잘하는데 ㅋㅋ 진짜 놀랬다] 는 (0.2476) 확률로 negative로 예상됩니다
# [ 말하면서 들어가는거 우원재 급인데 킹스트] 는 (0.3165) 확률로 negative로 예상됩니다
# [He is a korean] 는 (0.7311) 확률로 positive로 예상됩니다
# [He is my brother] 는 (0.8125) 확률로 positive로 예상됩니다
# [JJASTHIS] 는 (0.4611) 확률로 negative로 예상됩니다
# [내일은 감스트 프리스타일 랩 모음 올라갑니다 반응이 좋아서 유튜브에도 올리려고 합니다 알람설정 꼭 해주시고] 는 (0.8089) 확률로 positive로 예상됩니다
# [내일 많이봐주세요 그리고 오늘영상 좋아요 댓글 꼭 좀 부탁드립니다] 는 (0.9803) 확률로 positive로 예상됩니다
# [한사람의 인생을 바꿔놓은 한전드 그는 대체 인직이 쉔 진짜 며칠 전까지만 해도 병쉔이었는데 반병쉔 수준까지 올라왔더라] 는 (0.6607) 확률로 positive로 예상됩니다
# [스트는 명확하고 깔끔하게 오더해주는 팀이랑 잘맞음 자아생기지 못하게 잘 컨트롤 해줘야돼] 는 (0.7301) 확률로 positive로 예상됩니다
# [상윤 선생님이 ㄹㅇ 미친거같긴하다] 는 (0.6972) 확률로 positive로 예상됩니다
# [감스트가 치고 빠지기를 한다고 와우] 는 (0.7672) 확률로 positive로 예상됩니다
# [상윤이 코칭 받으면서 조금씩 느는게 느껴진다 근데 레넥은 하지마라ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.7378) 확률로 positive로 예상됩니다
# [ 탱글스트] 는 (0.4611) 확률로 negative로 예상됩니다
# [감스트 롤 영상을 이렇게 진지하게 본적은 처음임] 는 (0.6750) 확률로 positive로 예상됩니다
# [  ㄹㅇㅋㅋ ㅈㄴ 웃기다] 는 (0.5380) 확률로 positive로 예상됩니다
# [ 니실감에 발작하네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4134) 확률로 negative로 예상됩니다
# [ ㅈㄴ귀엽네 ㅋㅋㅋ] 는 (0.6016) 확률로 positive로 예상됩니다
# [ 레넥장인 ㅌㅌㅌㅌ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ㅋㅋㅋㅋㅋㅋ 감스트가 못한다고 놀리면 진짜로 억울해하네 ㅋㅋㅋㅋㅋ] 는 (0.6283) 확률로 positive로 예상됩니다
# [ 자크 지렸다 ㄹㅇ ] 는 (0.3618) 확률로 negative로 예상됩니다
# [이때 생방봤는데 감스트가 잘하니까 재밌어서 못나가게 되더라 ㅋㅋㅋㅋ 상윤덕이 크긴한듯] 는 (0.9154) 확률로 positive로 예상됩니다
# [ 싸우다가 포션도 먹는다고] 는 (0.4142) 확률로 negative로 예상됩니다
# [ 탸탸탸탸탸타] 는 (0.4611) 확률로 negative로 예상됩니다
# [  감세돌 씨익] 는 (0.2261) 확률로 negative로 예상됩니다
# [ ㅇㄴㅊㅂㄹㄴㄱㅁㅇㅁㅇㅅㅇ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 도주플레이ㅋ 감스트 맞아 너누구야 ] 는 (0.6357) 확률로 positive로 예상됩니다
# [상윤의 매운맛 인정이다ㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [은혜 갚는 까치에 빙의해서 평생 지키겠읍니다감사합니다 감스트가 보우하사  다슬 나라 만세 ] 는 (0.8557) 확률로 positive로 예상됩니다
# [감순이로 살다가 BJ가 되니 오빠를 접하게 되다니가문의영광이에여 ] 는 (0.1755) 확률로 negative로 예상됩니다
# [눈사람 만들어 놓을테니 다음에 싸커킥 제대로 배우고 싶습니다] 는 (0.5201) 확률로 positive로 예상됩니다
# [감빡이 감순이 화이팅] 는 (0.9933) 확률로 positive로 예상됩니다
# [아니 처음 회사원분ㅋㄱㄱㄱㄱㄱㅋ] 는 (0.1090) 확률로 negative로 예상됩니다
# [부사장님이랑 존나 사촌오빠 사촌동생사이느낌으로 지내는것도 신기하고 춤쳐도 반응좋고 대표님이 인직이보고 ㅈ같이생겼다고 바로 욕박는것도 개쳐웃기고 회사 존나 프리하네ㅋㅋㄱㄲㅋㄱㄱㄱㄱㅋ] 는 (0.5268) 확률로 positive로 예상됩니다
# [와중에 이쁘고 몸매도 좋음ㅋㅋㅋㅋㅋ 매력미쳣네] 는 (0.7794) 확률로 positive로 예상됩니다
# [나도 저기 입사할래 ㅋㅋㄱㅋ] 는 (0.5854) 확률로 positive로 예상됩니다
# [쿠크다슬도 승무원 준비했다는데 스트 기가 막히게 승무원상 찾아내네 감카우터 성능 오우오우] 는 (0.5276) 확률로 positive로 예상됩니다
# [같이 살자고 홍보해주는 감스트보면 진짜 인성하나는 멋있는것 같다 진짜 머리만 심자 형 사랑해] 는 (0.8570) 확률로 positive로 예상됩니다
# [얘들아 쿠크다슬 낼 시에 생방이야 추천박아서 널리 알리자] 는 (0.5554) 확률로 positive로 예상됩니다
# [형땜에 눈이 높아졌어쿠크다슬] 는 (0.4830) 확률로 negative로 예상됩니다
# [ 스켈레톤식 ㅅㅂㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [인직 나만봐 그리고 미리 만 축하해 만 남았다 까먹은 사람들 얼른 눌러라잇 ] 는 (0.5664) 확률로 positive로 예상됩니다
# [ 존잘의 삶 부럽다] 는 (0.9315) 확률로 positive로 예상됩니다
# [세분 다 레전드네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 쿠크다슬님 텐션이 레전드다] 는 (0.6465) 확률로 positive로 예상됩니다
# [ 저때 얼굴이 ㄹㅈㄷ지 ㅋㅋㅋㅋㅋ] 는 (0.7500) 확률로 positive로 예상됩니다
# [ 안면 함몰ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 멘트 선정도 개웃기네] 는 (0.1494) 확률로 negative로 예상됩니다
# [ 아 개귀여웤ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [진짜 이 분들 반응 보면 감스트가 정말 아프리카 bj 원탑이라는 걸 느끼게 해줌] 는 (0.8529) 확률로 positive로 예상됩니다
# [ 개뿜었네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [쿠크다슬 입덕일차이 여자 뭐야] 는 (0.0027) 확률로 negative로 예상됩니다
# [ 개레전드 ㅅㅂㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [쿠쿠다슬 저분 정말 순수하다 귀엽네] 는 (0.8272) 확률로 positive로 예상됩니다
# [ 매니저 ㅅㅂ 레게련아 감스트 왔음 ㅇㅈㄹㅋㅋㅋㅋㅋ] 는 (0.0377) 확률로 negative로 예상됩니다
# [쿠붕이 재밌게 놀다 갑니다 다음에 또 같이 해요ㅎㅎ] 는 (0.9559) 확률로 positive로 예상됩니다
# [ㄹㅇ 마형 옆에서 보니깐 클라스 더지렸습니다 마린이 말도안되는 이유가있다] 는 (0.1413) 확률로 negative로 예상됩니다
# [유튜브 오류 뭐냐 진짜 ] 는 (0.1342) 확률로 negative로 예상됩니다
# [마린이 레전드인 이유가 페이커를 꺾고 mvp받음] 는 (0.0770) 확률로 negative로 예상됩니다
# [ 쿠세블리 오열ㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [마린 한국을 대표] 는 (0.5177) 확률로 positive로 예상됩니다
# [인직 북한을 대표] 는 (0.6210) 확률로 positive로 예상됩니다
# [ 스트머리에 창 꽂힘] 는 (0.4611) 확률로 negative로 예상됩니다
# [도파 마린은 우리나라가 국제대회를 호령하던 그 영광스러운 시절의 주인공이다] 는 (0.8810) 확률로 positive로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [그 주인공이 되려면 탑에서 을 해야한다 메모] 는 (0.2225) 확률로 negative로 예상됩니다
# [ 반박불가] 는 (0.3628) 확률로 negative로 예상됩니다
# [ 구거존나 잘한다 진짜 ㅋㅋㅋ] 는 (0.8820) 확률로 positive로 예상됩니다
# [ 어이가없어서 웃기넼ㅋ] 는 (0.1068) 확률로 negative로 예상됩니다
# [ 저 창도 저렇게 가볍게 피하는게 프로구나] 는 (0.6997) 확률로 positive로 예상됩니다
# [ 이것두 지리네] 는 (0.2285) 확률로 negative로 예상됩니다
# [ 아니 쿠로 나노무빙 뭐야 ㅈㄴ 멋있어] 는 (0.2152) 확률로 negative로 예상됩니다
# [ 말파 부랄 ㄷㄷ] 는 (0.6607) 확률로 positive로 예상됩니다
# [ 진짜 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.7138) 확률로 positive로 예상됩니다
# [마린님 초대해서 한 감ck가 존잼 ㅋㅋㅋㅋ 행복롤하면서 승리까지 하는] 는 (0.9504) 확률로 positive로 예상됩니다
# [ 구거 플레이 ㄹㅇ미쳤다 ] 는 (0.2430) 확률로 negative로 예상됩니다
# [ 아펠궁 플써서 막은것도 미쳤다] 는 (0.4614) 확률로 negative로 예상됩니다
# [  쿠로 목소리 변화ㅋㅋㅋㅋㅋㅋ] 는 (0.3950) 확률로 negative로 예상됩니다
# [상윤말이 ㄹㅇ 맞네 ㅋㅋㅋ 장인 불러서 컨텐츠 한 다음에 선생님 바꾼다고 ㅋㅋㅋㅋ] 는 (0.4026) 확률로 negative로 예상됩니다
# [감크루 그냥 계속하자 계속해도 뭐라할사람 아무도 없으니까 그냥 영원히하자] 는 (0.0469) 확률로 negative로 예상됩니다
# [밧드 진짜 호감이네 크루원도 아니라 안해도 되는데 끝까지 같이 해줬네] 는 (0.3883) 확률로 negative로 예상됩니다
# [ He is Mario] 는 (0.7166) 확률로 positive로 예상됩니다
# [감크루하고나서 스트가 아이처럼 해맑게 웃는게 너무 좋다 감크루 행복하자 ] 는 (0.9903) 확률로 positive로 예상됩니다
# [ 여기부터 ㅈㄴ웃겼음] 는 (0.4883) 확률로 negative로 예상됩니다
# [  와 킹기훈 ㄷㄷㄷㄷㄷ 진짜 놀랐다] 는 (0.8252) 확률로 positive로 예상됩니다
# [ 너 누구야] 는 (0.0832) 확률로 negative로 예상됩니다
# [다른사람들도 다 고생했는데] 는 (0.4611) 확률로 negative로 예상됩니다
# [준밧드가 ㄹㅇ 의리있고 멋있더라] 는 (0.3833) 확률로 negative로 예상됩니다
# [처음에는 잘 못끼어들더니 술 들어가니 감크루 의멤번줄 욕심난다] 는 (0.4452) 확률로 negative로 예상됩니다
# [ 깨박이 술 옮기는 스킬 ㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3403) 확률로 negative로 예상됩니다
# [시청자들 웃길려고 눈치보고 드립날리는게 아니라 진짜 친구들끼리 놀러가서 뇌절도하고 이상한걸로도 다같이 웃고 하는게 너무 보기좋다] 는 (0.0540) 확률로 negative로 예상됩니다
# [ ㄴㄴㄱㄹㅇ 킹기훈 버전 왤케 웃기지 ㅋㅋㅋㅋㅅㅂ] 는 (0.0303) 확률로 negative로 예상됩니다
# [ 반갈ㅋㄱㅋㄱㅋ 개추억이네] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 무슨 기어세컨드냐고ㅋㅋㅋㅋ] 는 (0.0002) 확률로 negative로 예상됩니다
# [준밧드 감스트랑 계속 방송하는거 너무 좋고 앞으로도 계속해줬으면 좋겠다] 는 (0.9999) 확률로 positive로 예상됩니다
# [나락갈뻔했던거 염보성의 철원추천과 청자들이 옥상가자는거 그냥 철원간다는 감단으로 두 크루모두 극락갔던날] 는 (0.0039) 확률로 negative로 예상됩니다
# [이러니까 개콘이 망했지 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3152) 확률로 negative로 예상됩니다
# [여기선 편집되었지만 텐트안에서 나눈 진솔토크도 감동적이었음] 는 (0.4908) 확률로 negative로 예상됩니다
# [ 일본 장인이 끓인거얔ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.1454) 확률로 negative로 예상됩니다
# [ HOT ICE COFFEE] 는 (0.5809) 확률로 positive로 예상됩니다
# [인직아 개청자들 말 안 듣고 감단 내린거 좋았다] 는 (0.9250) 확률로 positive로 예상됩니다
# [원래 금요일은 영상안올리는데 내일은 올립니다 영상 좋아요좀 꼭 눌러주시고] 는 (0.8816) 확률로 positive로 예상됩니다
# [댓글좀 많이 달아주세요] 는 (0.3536) 확률로 negative로 예상됩니다
# [홀리 몰리] 는 (0.5766) 확률로 positive로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [대화 흐름 ㅅㅂ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.0067) 확률로 negative로 예상됩니다
# [ 킹기훈 팩폭ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 미쳤어 미쳤어 이ㅅㄲ 미쳤어] 는 (0.3554) 확률로 negative로 예상됩니다
# [ 상윤선생의 미쳤어 미쳤어] 는 (0.3554) 확률로 negative로 예상됩니다
# [이야 상윤이 잘 뽑았다 가르치는 법을 아네 ㅋㅋㅋㅋ 뭐해라 뭐해라가아닌 역질문을 해서 감스트가 제대로알고있는지 확인하고 바로 잡아주네  역질문 가르침이 효과가 좋긴함 감스트라그렇지] 는 (0.4695) 확률로 negative로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [기훈형이랑 스트형이랑 말하는거 너무 웃겨 ㅋㅋㅋㅋ] 는 (0.8693) 확률로 positive로 예상됩니다
# [특히 살인마 형님이시네 이부분 ㅋㅋ] 는 (0.9594) 확률로 positive로 예상됩니다
# [ 역시 가현바라기이십니다 행님] 는 (0.8086) 확률로 positive로 예상됩니다
# [사실 상윤이는 진짜 사랑의 매 느낌이 맞지 ㅋㅋ 선생 성격 안좋은 사람이엿으면 개패면서 할듯 ㅋㅋ] 는 (0.4497) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋ 킹기훈ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3618) 확률로 negative로 예상됩니다
# [진짜 상윤이 혼내는거에 대리만족느낌ㅋㅋㅋ] 는 (0.7138) 확률로 positive로 예상됩니다
# [상윤센세는 거의 조선시대로 치면] 는 (0.4388) 확률로 negative로 예상됩니다
# [왕한테 충언만하는 충신이네 ] 는 (0.5166) 확률로 positive로 예상됩니다
# [이걸원했다 ㅇㅈ] 는 (0.4611) 확률로 negative로 예상됩니다
# [새벽에 생방보니까 버릇 여전함배우나마나야ㅋㅋㅋ채팅창 계속더러워지고] 는 (0.8358) 확률로 positive로 예상됩니다
# [기훈이가 ㄹㅇ 개웃기네 ㅋㅋㅋ] 는 (0.2119) 확률로 negative로 예상됩니다
# [ 기의검 어디서 파는거야 ㅋㅋㅋㅋㅋㅋ] 는 (0.3772) 확률로 negative로 예상됩니다
# [상윤 진짜 선생님으로 잘뽑은듯ㅋㅋㅋ티키타카도 잘하고 스트형을 누구보다 찰지게 패ㅋㅋㅋㅋ] 는 (0.9060) 확률로 positive로 예상됩니다
# [이 분은 이 영상이 올라온 다음날 코ck에서 지금까지 판밖에 하지 않은 칼리스타를 픽한 뒤 엄청난 롤 실력을 보여주며 나락을 갔다고 한다] 는 (0.8953) 확률로 positive로 예상됩니다
# [진짜 상윤이 잘뽑았다 ㄹㅇ로] 는 (0.7138) 확률로 positive로 예상됩니다
# [킹기훈ㅋㅋㅋㅋㅈㄴ웃기네] 는 (0.4611) 확률로 negative로 예상됩니다
# [뒤에 기훈이 줫나 웃기네 ㅋㅋㅋㅋㅋㅋㅋ] 는 (0.5884) 확률로 positive로 예상됩니다
# [GAMSOOBOK] 는 (0.4611) 확률로 negative로 예상됩니다
# [  ] 는 (0.4611) 확률로 negative로 예상됩니다
# [아 존나 섹시해 이러니까 여자들이 뻑이가지] 는 (0.3171) 확률로 negative로 예상됩니다
# [ ㅈㄴ 귀엽네 ㅋㅋㅋㅋㅋㅋ] 는 (0.3108) 확률로 negative로 예상됩니다
# [ 진짜 존나 웃기네 ㅋㅋ] 는 (0.8005) 확률로 positive로 예상됩니다
# [최근 영상중에 제일 재밌었다 수복이 매력터져 ] 는 (0.9912) 확률로 positive로 예상됩니다
# [수감복 존버ㄷㄱㄷㄱ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 뛰어오는거 나만 귀여움] 는 (0.9926) 확률로 positive로 예상됩니다
# [ 번방의 수복 ㅋㅋ] 는 (0.8012) 확률로 positive로 예상됩니다
# [ 설레잉직] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 컬투쇼 김태균인줄 ㅋㅋ] 는 (0.9148) 확률로 positive로 예상됩니다
# [신입여캠이라 모두가 별로라고 했는데 레전드를 써버렸지 낮 방송 만이면 대성공이였다 수복누님의 또라이 같은면에 계속 보게 되더라] 는 (0.7234) 확률로 positive로 예상됩니다
# [  존나 카리스마 있어 ㅋ] 는 (0.9156) 확률로 positive로 예상됩니다
# [나르샤가 살짝 보이는거같기도] 는 (0.9536) 확률로 positive로 예상됩니다
# [ 어디서 많이 들은 말] 는 (0.1833) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4134) 확률로 negative로 예상됩니다
# [생각나는대로 대화하네 ㅋㅋ] 는 (0.9148) 확률로 positive로 예상됩니다
# [수복이 개매력터지네 ㅋㅋㅋㅋ] 는 (0.3618) 확률로 negative로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋ말 개웃기게 하네 거울보고 밥 잘드시자나요 그럼 댄거예요ㅋㅋㅋㅋ ㅇㅈㄹ] 는 (0.2105) 확률로 negative로 예상됩니다
# [ 박력직] 는 (0.4611) 확률로 negative로 예상됩니다
# [와 진짜 역대급 레게년이다 ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.9301) 확률로 positive로 예상됩니다
# [사람 되자 김인직] 는 (0.1783) 확률로 negative로 예상됩니다
# [와 상윤이가 진짜 속이 후련할 정도로 팩폭했네 키보드 난타하는 것도 좀 고쳐주면 더 바랄게 없을 듯 상윤아 제발 사람 만들어 주라 ] 는 (0.1583) 확률로 negative로 예상됩니다
# [삼위일체 못사는 이유 분석하는 거 보고 ㅈㄴ육성으로 터져버림ㅋㅋㅋㅋㅋㅋㅋ 왜 안사지지 머리 겁나 굴리는게 표정으로 드러남ㅋㅋㅋㅋㅋ] 는 (0.7363) 확률로 positive로 예상됩니다
# [눈가루 트할 선생님이 못 가르치는게 아니라 감스트가 아는 척 하는거다] 는 (0.8609) 확률로 positive로 예상됩니다
# [ㄹㅇ 명언이다] 는 (0.3452) 확률로 negative로 예상됩니다
# [ 파워레인져 인직포슼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.1651) 확률로 negative로 예상됩니다
# [오우 지미씹솨스것] 는 (0.9132) 확률로 positive로 예상됩니다
# [ 오우 파일에 기부주소 뭐야 ] 는 (0.1820) 확률로 negative로 예상됩니다
# [역시 인직] 는 (0.9925) 확률로 positive로 예상됩니다
# [Next is Gyo  roo] 는 (0.5883) 확률로 positive로 예상됩니다
# [ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아는척하니까 아는줄알고 다른거 가르친거잖앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아 개웃겨] 는 (0.3573) 확률로 negative로 예상됩니다
# [상윤 진짜 존나 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.7549) 확률로 positive로 예상됩니다
# [한전드 팩폭에 너무 속시원하다편안] 는 (0.4002) 확률로 negative로 예상됩니다
# [선생님 ㅈㄴ 잘뽑았네 진짜 ㅋㅋㅋㅋㅋㅋ ㅈㄴ속시원하다 진심 ㅋㅋㅋㅋㅋ] 는 (0.5389) 확률로 positive로 예상됩니다
# [그동안 선생님들은 게임 가이드 느낌 이였다면 상윤은 진짜 찐담임선생이다] 는 (0.4676) 확률로 negative로 예상됩니다
# [새로운 메타네 삼위일체  태불방ㅋㅋㅋㅋㅋㅋㅋ 트포 안사질 때 표정 씹레전드네] 는 (0.8481) 확률로 positive로 예상됩니다
# [리얼 선생님같앜ㅋㅋㅋㅋㅋ 개빡씬 선생님ㅋㅋㅋㅋ] 는 (0.8111) 확률로 positive로 예상됩니다
# [ 우물에서 분을 있네 ㅋㅋㅋ 사람인가] 는 (0.0569) 확률로 negative로 예상됩니다
# [지진의 종류 ㅇㅈㄹ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 눈물나오네] 는 (0.0912) 확률로 negative로 예상됩니다
# [나는상윤 말 ㅈㄴ 웃기고 ㅈㄴ 잘함ㅋㅋㅋ] 는 (0.5696) 확률로 positive로 예상됩니다
# [롤영상보면서 이렇게 웃은 적 처음이다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 너무 웃겨] 는 (0.9276) 확률로 positive로 예상됩니다
# [ 팩트폭행시작] 는 (0.4611) 확률로 negative로 예상됩니다
# [유도김민수 선생님입니다 이날 재미있게 수업하였습니다] 는 (0.9246) 확률로 positive로 예상됩니다
# [감스트님 유도 수업열정 참여  감사드립니다 다음 기회되면 또 같이 운동해요이상  샤크김민수입니다] 는 (0.7539) 확률로 positive로 예상됩니다
# [속보  감스트 중을 살으로 알아 ] 는 (0.8282) 확률로 positive로 예상됩니다
# [ 꼭 저러는 잼민이들 있음 ㅋㅋ] 는 (0.8095) 확률로 positive로 예상됩니다
# [ 초딩감남] 는 (0.4611) 확률로 negative로 예상됩니다
# [ PTSD ON] 는 (0.8966) 확률로 positive로 예상됩니다
# [감남존버ㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 세상편한 아기지렁이] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 오늘 가장 자연스러움] 는 (0.9559) 확률로 positive로 예상됩니다
# [감남순 존버] 는 (0.4611) 확률로 negative로 예상됩니다
# [제목만 봐도 재밌다] 는 (0.9370) 확률로 positive로 예상됩니다
# [인직남순존버] 는 (0.4611) 확률로 negative로 예상됩니다
# [ He is Rammus] 는 (0.7166) 확률로 positive로 예상됩니다
# [ 달달] 는 (0.9105) 확률로 positive로 예상됩니다
# [ 감지컬 ㄷ ㄷ ㄷ ㄷ ㄷ ㄷ ㄷ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ㅋㅋㅋㅋㅋㅋ남순이랑 둘이 기엽다 ㅋㅋㅋㅋ] 는 (0.5026) 확률로 positive로 예상됩니다
# [ 뒤진다 앞에 뭐가 있었던거 같은데] 는 (0.0194) 확률로 negative로 예상됩니다
# [남순이랑 감스트 초딩 노는거 처럼 노네 ㅋㅋㅋㅋㅋ] 는 (0.3323) 확률로 negative로 예상됩니다
# [감남 잼민이 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.2324) 확률로 negative로 예상됩니다
# [스트형이 남순님 때리는거 개귀여움ㅋㅋㅋ 애기가 장난치는거 같음ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.5188) 확률로 positive로 예상됩니다
# [감남 ㅈㄴ 웃기네 남순이랑 초딩둘 ㅋㅋㅋ] 는 (0.7403) 확률로 positive로 예상됩니다
# [풀버전 httpsyoutubeRBvQfrLgUE] 는 (0.4611) 확률로 negative로 예상됩니다
# [ㅋㅋㅋㄲㄱㄲㅋㅋㄱㅋㄲㅋㅋㄲㅋ 오ㅅㅂㄹ ] 는 (0.4611) 확률로 negative로 예상됩니다
# [다들 너무 고생 많았구 재밌었습니다  D] 는 (0.9845) 확률로 positive로 예상됩니다
# [ 레전드 부분] 는 (0.9719) 확률로 positive로 예상됩니다
# [ 크로마키 인궁] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 상윤이 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.2125) 확률로 negative로 예상됩니다
# [ 썸넬 합성인줄 알았는데 ㄹㅇ이였네 ㅋㅋㅋㅋㅋ] 는 (0.8262) 확률로 positive로 예상됩니다
# [영상 좋아요 좀 눌러주세요] 는 (0.9343) 확률로 positive로 예상됩니다
# [ 이멤버 리멤버] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 코끼리 소리나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4170) 확률로 negative로 예상됩니다
# [오세블리 볼때마다 실버인지 브론즈 티어로 뽑혀서 챌 그마 상대로 할 수 있는거 다하고 힘들었을텐데 솔직히 오세블리가 자기 못한거 다 알고 제일 슬플텐데 쪽지로 뭐라하는건 그렇다 힘네세요] 는 (0.2033) 확률로 negative로 예상됩니다
# [겜스트에 풀버전 올려줄때까지 숨 참는다 흡] 는 (0.1583) 확률로 negative로 예상됩니다
# [오세블리한테 쪽지까지 쳐보내서 욕하는 새끼들은 ㅋㅋ 진짜 평소 행실이 보인다] 는 (0.3925) 확률로 negative로 예상됩니다
# [ 갓성은의 저주가 또] 는 (0.2912) 확률로 negative로 예상됩니다
# [상윤 저 입담 참느라 어케 프로게이머했냐 ㅋㅋㅋㅋㅋㅋ] 는 (0.5348) 확률로 positive로 예상됩니다
# [ 다들 놀랄때 준밧드 혼자 신난아이처럼 웃고있음 ㅋㅋㅋㅋㅋㅋㅋ] 는 (0.5018) 확률로 positive로 예상됩니다
# [   울거면 캠 키고 울어라ㅋㅋㅋㅋㅋ] 는 (0.2991) 확률로 negative로 예상됩니다
# [ 구거도 웃참ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 와 씨 보자마자 쌌다] 는 (0.7561) 확률로 positive로 예상됩니다
# [나는 상윤 감좋네 ㅋㅋ 보라 자주 나와라] 는 (0.7778) 확률로 positive로 예상됩니다
# [레전드 영상 제발 그만보세요] 는 (0.8733) 확률로 positive로 예상됩니다
# [만뷰 찍으면 인직이 고소 들어갑니다ㅎ] 는 (0.0772) 확률로 negative로 예상됩니다
# [사는게 힘들때마다 와서 봅니다] 는 (0.7293) 확률로 positive로 예상됩니다
# [감스트는 진짜 포병지 사건 전과 후로 나뉜다고 생각한다] 는 (0.6745) 확률로 positive로 예상됩니다
# [똥 먹어본 사람 좋아요] 는 (0.9863) 확률로 positive로 예상됩니다
# [솔직히 김병지가 해도 저 지랄  했을걸ㅋㅋㅋㅋ] 는 (0.0174) 확률로 negative로 예상됩니다
# [ 개인적으로 가자 이거 개웃김ㅋㅋ] 는 (0.7787) 확률로 positive로 예상됩니다
# [인물백과사전에서 보고 다시 병지 마려워서 온사람] 는 (0.9882) 확률로 positive로 예상됩니다
# [ 아 물론 한개로 ㅇㅈㄹ ㅋㅋㅋㅋㅋㅋ] 는 (0.6301) 확률로 positive로 예상됩니다
# [저 날 세상에서 제일 불쌍한 사람은 엄탱님이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.8421) 확률로 positive로 예상됩니다
# [ 어디서 원숭이짖는 소리가 나노ㅋㅋㅋ] 는 (0.1091) 확률로 negative로 예상됩니다
# [이날 포병지가 없었다면] 는 (0.2168) 확률로 negative로 예상됩니다
# [지금의 감스트도 없었고] 는 (0.7897) 확률로 positive로 예상됩니다
# [지금의 꽁병지tv도 없었지] 는 (0.9409) 확률로 positive로 예상됩니다
# [이모든걸 해낸 엄탱좌 그는 대체] 는 (0.3185) 확률로 negative로 예상됩니다
# [가짜사나이 면접영상 보고 포병지 보러왔읍니다] 는 (0.8104) 확률로 positive로 예상됩니다
# [인생만사 새옹지마라 포병지가 처음 떳을때는 운 개조졌구나 생각했겠지만 사실 감스트인생 최고의 행운이었다] 는 (0.9728) 확률로 positive로 예상됩니다
# [진짜 그만 오고싶다] 는 (0.0337) 확률로 negative로 예상됩니다
# [킹병지 가짜사나이리뷰 보고 다시 왔다 쓰벌] 는 (0.9632) 확률로 positive로 예상됩니다
# [  어린이날 기념 포병지 시청중인 사람] 는 (0.3037) 확률로 negative로 예상됩니다
# [이때 당시 시청자들 생중계 반응 궁금하닼ㅋㅋㅋㅋ] 는 (0.7511) 확률로 positive로 예상됩니다
# [오늘의 감스트를 있게 해준 영상] 는 (0.8531) 확률로 positive로 예상됩니다
# [샷건 칠때마다 마우스 움직이는거 개웃기네 진짜ㅋㅋㅋㅋㅋ] 는 (0.2654) 확률로 negative로 예상됩니다
# [손흥민인직이형 오늘 골 넣었는데 그럼 포흥민이라고 불러야 되나요] 는 (0.3916) 확률로 negative로 예상됩니다
# [방송적으로 잘받아주시고 철없는절 이끌어주셔서 감사합니다 덕분에 좋은방송 했어요 정말 감사합니다] 는 (0.9060) 확률로 positive로 예상됩니다
# [ 인직이 기분좋게해줄께] 는 (0.4611) 확률로 negative로 예상됩니다
# [이거는 봐도봐도 질리지가 않네 ㅌㅋㅋㅋㅋ] 는 (0.9247) 확률로 positive로 예상됩니다
# [ 같이 저러는 거 개 웃기네 아 ㅋㅋ 귀엽] 는 (0.8400) 확률로 positive로 예상됩니다
# [ 수찬 반응 느린거 나만 웃긴가] 는 (0.7400) 확률로 positive로 예상됩니다
# [인지기 이로와 오빠가 기분좋게해줄게] 는 (0.4686) 확률로 negative로 예상됩니다
# [ 화장실 불을 끄고 들어가네] 는 (0.2149) 확률로 negative로 예상됩니다
# [  잉직이형 맞는거 왤케 귀엽냐ㅋㅋ] 는 (0.1642) 확률로 negative로 예상됩니다
# [휴 인직이가 고딩 아니라 다행] 는 (0.0533) 확률로 negative로 예상됩니다
# [전수찬 존망한거 보고 다시 옴] 는 (0.9882) 확률로 positive로 예상됩니다
# [ 스트의 뻘쭘한 손ㅋㅋ] 는 (0.5625) 확률로 positive로 예상됩니다
# [섹수찬 사건 터지고 온사람] 는 (0.2683) 확률로 negative로 예상됩니다
# [ 표정 ㄹㅇ 개웃기네ㅋㅋㄱㅋㅋㅋ] 는 (0.4710) 확률로 negative로 예상됩니다
# [ 발 둘이 표정 진국이네ㅋㅋㅋㅋ] 는 (0.7082) 확률로 positive로 예상됩니다
# [ 이거진짜 개귀엽다 ㅋㅋㅋㅋㅋ] 는 (0.9340) 확률로 positive로 예상됩니다
# [ 너가 이제 사행성이네] 는 (0.1734) 확률로 negative로 예상됩니다
# [ 가서 머리나 심고오자잉  웃기닼ㅋㅋㅋ] 는 (0.3960) 확률로 negative로 예상됩니다
# [ ㅋㄱㅌㄱㅌㄱㄱㅋㅋㅋ개웃기네] 는 (0.4611) 확률로 negative로 예상됩니다
# [둘이 케미 미쳤넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 감스트 롤합방중에 제일 재밌다 ㅋㅋㅋㅋㅋ] 는 (0.9475) 확률로 positive로 예상됩니다
# [ 제자는 북한사람이야] 는 (0.3019) 확률로 negative로 예상됩니다
# [ O] 는 (0.4611) 확률로 negative로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 마리오 점프] 는 (0.2749) 확률로 negative로 예상됩니다
# [ 빌드업 시작 ㅋㅋㅋ] 는 (0.8841) 확률로 positive로 예상됩니다
# [ 걱정해주는 마음을 알고 바뀌는 직의 표정] 는 (0.9694) 확률로 positive로 예상됩니다
# [ 버벅대는거 ㅈㄴ웃기네] 는 (0.4611) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋㅋ노공만 신나서 신발들고왔는데 조롱당하는거보고 굳어버리네 ㅋㅋ] 는 (0.6177) 확률로 positive로 예상됩니다
# [ 부담스럽게 점점 얼굴이 커져버리기] 는 (0.2595) 확률로 negative로 예상됩니다
# [ 갑자기 눈썹 올라감ㅋㅋㄱㄱㅋㄱㅋㄱㅋ] 는 (0.0721) 확률로 negative로 예상됩니다
# [ 시청자분 당황해서 헛웃음 나오는거 눈물난다 괜히 그 타이밍에 전화를 해서 ] 는 (0.0973) 확률로 negative로 예상됩니다
# [O 폭주 기관차연속으로 누르세여] 는 (0.4406) 확률로 negative로 예상됩니다
# [ 역사책 보내준다니까 팔만대장경보내라네ㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 채팅창 카메라 그만쳐다봐 키스 개갈기고싶으니까] 는 (0.3194) 확률로 negative로 예상됩니다
# [ 존나윳기네 ㅋㅋ시바] 는 (0.4611) 확률로 negative로 예상됩니다
# [오랜만에 봤는데 너무 웃기네 ㅋㅋㅋㅋ] 는 (0.9589) 확률로 positive로 예상됩니다
# [ 인정충 개레전드] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 맨만기 등판] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 이부분 개조앜ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 부터 자기소개시작] 는 (0.6359) 확률로 positive로 예상됩니다
# [ 이때부터 mbc를 노린거냐 인직] 는 (0.5291) 확률로 positive로 예상됩니다
# [이때가 그립다 소소한 시청자들과 진짜 팬들로 이루어져서 이야기하는게] 는 (0.9470) 확률로 positive로 예상됩니다
# [ up] 는 (0.8910) 확률로 positive로 예상됩니다
# [느슨해진 한국힙합에 긴장감을 주는 것 같다] 는 (0.8732) 확률로 positive로 예상됩니다
# [지금도 듣는 감빡이 있나 에이 Yo] 는 (0.4127) 확률로 negative로 예상됩니다
# [단단했던 한국힙합에 느슨함을 주는것 같다] 는 (0.4961) 확률로 negative로 예상됩니다
# [월 일 듣는 사람 있냐 난 장사하는데 ㄹㅇ 이거 오픈때 틀면 그 날 장사 잘되고 마감때 틀면 다음 날 잘 된다 진짜 감빡이 필수곡이다] 는 (0.3003) 확률로 negative로 예상됩니다
# [ZZASTHIS Family] 는 (0.3820) 확률로 negative로 예상됩니다
# [감스트랑 유알콜까지만 듣고 끄는게 국룰] 는 (0.3923) 확률로 negative로 예상됩니다
# [월에도 못 끊겠네 너란 남자 인직한다] 는 (0.4654) 확률로 negative로 예상됩니다
# [이거 수녀형이 리액션한번 하면 좋겠다] 는 (0.7503) 확률로 positive로 예상됩니다
# [ 여기서 어떻게든 끝냈어야 했어] 는 (0.0437) 확률로 negative로 예상됩니다
# [월 아직보는사람] 는 (0.4611) 확률로 negative로 예상됩니다
# [월일 아직보는사람있나] 는 (0.4611) 확률로 negative로 예상됩니다
# [회사 있어요] 는 (0.9612) 확률로 positive로 예상됩니다
# [아직도 듣고 있는 사람 있나] 는 (0.7819) 확률로 positive로 예상됩니다
# [ 농협 해쉬 카 ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3834) 확률로 negative로 예상됩니다
# [At first I thought it was a joke music video] 는 (0.8325) 확률로 positive로 예상됩니다
# [Im surprised how really good this rap song is Respect] 는 (0.4061) 확률로 negative로 예상됩니다
# [저스디스가 이 영상을 좋아합니다] 는 (0.6780) 확률로 positive로 예상됩니다
# [설마가아니라 감빡이들의 하루 마무리곡이야] 는 (0.7615) 확률로 positive로 예상됩니다
# [감스트 릴카 존버] 는 (0.4611) 확률로 negative로 예상됩니다
# [우산듣고온사람 조용히 추천박아라] 는 (0.5469) 확률로 positive로 예상됩니다
# [영상 좋아요 한번씩 부탁드립니다] 는 (0.9692) 확률로 positive로 예상됩니다
# [형 우리 아버지랑  붙어볼래] 는 (0.8773) 확률로 positive로 예상됩니다
# [ 롯데리아 세트 레게놐ㅋㅋㅋㅋㅋ] 는 (0.3792) 확률로 negative로 예상됩니다
# [ 노래 나오다가 패배 개웃기넼ㅋㅋㅋㅋㅋ] 는 (0.8205) 확률로 positive로 예상됩니다
# [ 라잌ㅋㅋㅋㅋㅋㅋ 존나 웃기넼ㅋㅋ] 는 (0.1370) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋ ㅅㅂ 냄새 진짜 나는거같아] 는 (0.1021) 확률로 negative로 예상됩니다
# [ 시비르 채팅 ㅅㅂㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3289) 확률로 negative로 예상됩니다
# [ 트름 후 멘트가 존내 웃기네 ㅋㅋㅋ] 는 (0.8367) 확률로 positive로 예상됩니다
# [ 상체 위압감 ㄷㄷ] 는 (0.6607) 확률로 positive로 예상됩니다
# [사골국보다 더 우려먹는데 개재밌네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.6350) 확률로 positive로 예상됩니다
# [형 이제 슬슬 프로필사진 내려야 할 것 같다ㅋㅋㅋ] 는 (0.0707) 확률로 negative로 예상됩니다
# [ 에 기훈이 왜 찌찌만지놐ㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 거창하게 트림하고 악마드립치는거 개웃기네 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4541) 확률로 negative로 예상됩니다
# [ 킹기훈 인싸력 실화냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.7468) 확률로 positive로 예상됩니다
# [ 악마살고있대 미쳤네 ㅋㅋㅋㅋㅋㅋ] 는 (0.4313) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아니 ㅈㄴ 뜸금없이 팩트를 날렼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.2505) 확률로 negative로 예상됩니다
# [ 뜬금없이 개웃기네 ㅋㅋㅋㅋ] 는 (0.0286) 확률로 negative로 예상됩니다
# [ 아 진짜 개웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4855) 확률로 negative로 예상됩니다
# [ 뒤에서 감스트 웃는게 제일 웃기네 ㅋㅋ] 는 (0.8821) 확률로 positive로 예상됩니다
# [ 다 똑같이 생겨가지고 개웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3544) 확률로 negative로 예상됩니다
# [레전드 영상 제발 그만보세요] 는 (0.8733) 확률로 positive로 예상됩니다
# [만뷰 찍으면 인직이 고소 들어갑니다ㅎ] 는 (0.0772) 확률로 negative로 예상됩니다
# [사는게 힘들때마다 와서 봅니다] 는 (0.7293) 확률로 positive로 예상됩니다
# [감스트는 진짜 포병지 사건 전과 후로 나뉜다고 생각한다] 는 (0.6745) 확률로 positive로 예상됩니다
# [똥 먹어본 사람 좋아요] 는 (0.9863) 확률로 positive로 예상됩니다
# [솔직히 김병지가 해도 저 지랄  했을걸ㅋㅋㅋㅋ] 는 (0.0174) 확률로 negative로 예상됩니다
# [ 개인적으로 가자 이거 개웃김ㅋㅋ] 는 (0.7787) 확률로 positive로 예상됩니다
# [인물백과사전에서 보고 다시 병지 마려워서 온사람] 는 (0.9882) 확률로 positive로 예상됩니다
# [ 아 물론 한개로 ㅇㅈㄹ ㅋㅋㅋㅋㅋㅋ] 는 (0.6301) 확률로 positive로 예상됩니다
# [저 날 세상에서 제일 불쌍한 사람은 엄탱님이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.8421) 확률로 positive로 예상됩니다
# [ 어디서 원숭이짖는 소리가 나노ㅋㅋㅋ] 는 (0.1091) 확률로 negative로 예상됩니다
# [이날 포병지가 없었다면] 는 (0.2168) 확률로 negative로 예상됩니다
# [지금의 감스트도 없었고] 는 (0.7897) 확률로 positive로 예상됩니다
# [지금의 꽁병지tv도 없었지] 는 (0.9409) 확률로 positive로 예상됩니다
# [이모든걸 해낸 엄탱좌 그는 대체] 는 (0.3185) 확률로 negative로 예상됩니다
# [가짜사나이 면접영상 보고 포병지 보러왔읍니다] 는 (0.8104) 확률로 positive로 예상됩니다
# [인생만사 새옹지마라 포병지가 처음 떳을때는 운 개조졌구나 생각했겠지만 사실 감스트인생 최고의 행운이었다] 는 (0.9728) 확률로 positive로 예상됩니다
# [진짜 그만 오고싶다] 는 (0.0337) 확률로 negative로 예상됩니다
# [킹병지 가짜사나이리뷰 보고 다시 왔다 쓰벌] 는 (0.9632) 확률로 positive로 예상됩니다
# [  어린이날 기념 포병지 시청중인 사람] 는 (0.3037) 확률로 negative로 예상됩니다
# [이때 당시 시청자들 생중계 반응 궁금하닼ㅋㅋㅋㅋ] 는 (0.7511) 확률로 positive로 예상됩니다
# [오늘의 감스트를 있게 해준 영상] 는 (0.8531) 확률로 positive로 예상됩니다
# [샷건 칠때마다 마우스 움직이는거 개웃기네 진짜ㅋㅋㅋㅋㅋ] 는 (0.2654) 확률로 negative로 예상됩니다
# [손흥민인직이형 오늘 골 넣었는데 그럼 포흥민이라고 불러야 되나요] 는 (0.3916) 확률로 negative로 예상됩니다
# [방송적으로 잘받아주시고 철없는절 이끌어주셔서 감사합니다 덕분에 좋은방송 했어요 정말 감사합니다] 는 (0.9060) 확률로 positive로 예상됩니다
# [ 인직이 기분좋게해줄께] 는 (0.4611) 확률로 negative로 예상됩니다
# [이거는 봐도봐도 질리지가 않네 ㅌㅋㅋㅋㅋ] 는 (0.9247) 확률로 positive로 예상됩니다
# [ 같이 저러는 거 개 웃기네 아 ㅋㅋ 귀엽] 는 (0.8400) 확률로 positive로 예상됩니다
# [ 수찬 반응 느린거 나만 웃긴가] 는 (0.7400) 확률로 positive로 예상됩니다
# [인지기 이로와 오빠가 기분좋게해줄게] 는 (0.4686) 확률로 negative로 예상됩니다
# [ 화장실 불을 끄고 들어가네] 는 (0.2149) 확률로 negative로 예상됩니다
# [  잉직이형 맞는거 왤케 귀엽냐ㅋㅋ] 는 (0.1642) 확률로 negative로 예상됩니다
# [휴 인직이가 고딩 아니라 다행] 는 (0.0533) 확률로 negative로 예상됩니다
# [전수찬 존망한거 보고 다시 옴] 는 (0.9882) 확률로 positive로 예상됩니다
# [ 스트의 뻘쭘한 손ㅋㅋ] 는 (0.5625) 확률로 positive로 예상됩니다
# [섹수찬 사건 터지고 온사람] 는 (0.2683) 확률로 negative로 예상됩니다
# [ 표정 ㄹㅇ 개웃기네ㅋㅋㄱㅋㅋㅋ] 는 (0.4710) 확률로 negative로 예상됩니다
# [ 발 둘이 표정 진국이네ㅋㅋㅋㅋ] 는 (0.7082) 확률로 positive로 예상됩니다
# [ 이거진짜 개귀엽다 ㅋㅋㅋㅋㅋ] 는 (0.9340) 확률로 positive로 예상됩니다
# [ 너가 이제 사행성이네] 는 (0.1734) 확률로 negative로 예상됩니다
# [ 가서 머리나 심고오자잉  웃기닼ㅋㅋㅋ] 는 (0.3960) 확률로 negative로 예상됩니다
# [ ㅋㄱㅌㄱㅌㄱㄱㅋㅋㅋ개웃기네] 는 (0.4611) 확률로 negative로 예상됩니다
# [둘이 케미 미쳤넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 감스트 롤합방중에 제일 재밌다 ㅋㅋㅋㅋㅋ] 는 (0.9475) 확률로 positive로 예상됩니다
# [ 제자는 북한사람이야] 는 (0.3019) 확률로 negative로 예상됩니다
# [ O] 는 (0.4611) 확률로 negative로 예상됩니다
# [] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 마리오 점프] 는 (0.2749) 확률로 negative로 예상됩니다
# [ 빌드업 시작 ㅋㅋㅋ] 는 (0.8841) 확률로 positive로 예상됩니다
# [ 걱정해주는 마음을 알고 바뀌는 직의 표정] 는 (0.9694) 확률로 positive로 예상됩니다
# [ 버벅대는거 ㅈㄴ웃기네] 는 (0.4611) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋㅋ노공만 신나서 신발들고왔는데 조롱당하는거보고 굳어버리네 ㅋㅋ] 는 (0.6177) 확률로 positive로 예상됩니다
# [ 부담스럽게 점점 얼굴이 커져버리기] 는 (0.2595) 확률로 negative로 예상됩니다
# [ 갑자기 눈썹 올라감ㅋㅋㄱㄱㅋㄱㅋㄱㅋ] 는 (0.0721) 확률로 negative로 예상됩니다
# [ 시청자분 당황해서 헛웃음 나오는거 눈물난다 괜히 그 타이밍에 전화를 해서 ] 는 (0.0973) 확률로 negative로 예상됩니다
# [O 폭주 기관차연속으로 누르세여] 는 (0.4406) 확률로 negative로 예상됩니다
# [ 역사책 보내준다니까 팔만대장경보내라네ㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 채팅창 카메라 그만쳐다봐 키스 개갈기고싶으니까] 는 (0.3194) 확률로 negative로 예상됩니다
# [ 존나윳기네 ㅋㅋ시바] 는 (0.4611) 확률로 negative로 예상됩니다
# [오랜만에 봤는데 너무 웃기네 ㅋㅋㅋㅋ] 는 (0.9589) 확률로 positive로 예상됩니다
# [ 인정충 개레전드] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 맨만기 등판] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 이부분 개조앜ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 부터 자기소개시작] 는 (0.6359) 확률로 positive로 예상됩니다
# [ 이때부터 mbc를 노린거냐 인직] 는 (0.5291) 확률로 positive로 예상됩니다
# [이때가 그립다 소소한 시청자들과 진짜 팬들로 이루어져서 이야기하는게] 는 (0.9470) 확률로 positive로 예상됩니다
# [ up] 는 (0.8910) 확률로 positive로 예상됩니다
# [느슨해진 한국힙합에 긴장감을 주는 것 같다] 는 (0.8732) 확률로 positive로 예상됩니다
# [지금도 듣는 감빡이 있나 에이 Yo] 는 (0.4127) 확률로 negative로 예상됩니다
# [단단했던 한국힙합에 느슨함을 주는것 같다] 는 (0.4961) 확률로 negative로 예상됩니다
# [월 일 듣는 사람 있냐 난 장사하는데 ㄹㅇ 이거 오픈때 틀면 그 날 장사 잘되고 마감때 틀면 다음 날 잘 된다 진짜 감빡이 필수곡이다] 는 (0.3003) 확률로 negative로 예상됩니다
# [ZZASTHIS Family] 는 (0.3820) 확률로 negative로 예상됩니다
# [감스트랑 유알콜까지만 듣고 끄는게 국룰] 는 (0.3923) 확률로 negative로 예상됩니다
# [월에도 못 끊겠네 너란 남자 인직한다] 는 (0.4654) 확률로 negative로 예상됩니다
# [이거 수녀형이 리액션한번 하면 좋겠다] 는 (0.7503) 확률로 positive로 예상됩니다
# [ 여기서 어떻게든 끝냈어야 했어] 는 (0.0437) 확률로 negative로 예상됩니다
# [월 아직보는사람] 는 (0.4611) 확률로 negative로 예상됩니다
# [월일 아직보는사람있나] 는 (0.4611) 확률로 negative로 예상됩니다
# [회사 있어요] 는 (0.9612) 확률로 positive로 예상됩니다
# [아직도 듣고 있는 사람 있나] 는 (0.7819) 확률로 positive로 예상됩니다
# [ 농협 해쉬 카 ㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3834) 확률로 negative로 예상됩니다
# [At first I thought it was a joke music video] 는 (0.8325) 확률로 positive로 예상됩니다
# [Im surprised how really good this rap song is Respect] 는 (0.4061) 확률로 negative로 예상됩니다
# [저스디스가 이 영상을 좋아합니다] 는 (0.6780) 확률로 positive로 예상됩니다
# [설마가아니라 감빡이들의 하루 마무리곡이야] 는 (0.7615) 확률로 positive로 예상됩니다
# [감스트 릴카 존버] 는 (0.4611) 확률로 negative로 예상됩니다
# [우산듣고온사람 조용히 추천박아라] 는 (0.5469) 확률로 positive로 예상됩니다
# [영상 좋아요 한번씩 부탁드립니다] 는 (0.9692) 확률로 positive로 예상됩니다
# [형 우리 아버지랑  붙어볼래] 는 (0.8773) 확률로 positive로 예상됩니다
# [ 롯데리아 세트 레게놐ㅋㅋㅋㅋㅋ] 는 (0.3792) 확률로 negative로 예상됩니다
# [ 노래 나오다가 패배 개웃기넼ㅋㅋㅋㅋㅋ] 는 (0.8205) 확률로 positive로 예상됩니다
# [ 라잌ㅋㅋㅋㅋㅋㅋ 존나 웃기넼ㅋㅋ] 는 (0.1370) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋ ㅅㅂ 냄새 진짜 나는거같아] 는 (0.1021) 확률로 negative로 예상됩니다
# [ 시비르 채팅 ㅅㅂㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3289) 확률로 negative로 예상됩니다
# [ 트름 후 멘트가 존내 웃기네 ㅋㅋㅋ] 는 (0.8367) 확률로 positive로 예상됩니다
# [ 상체 위압감 ㄷㄷ] 는 (0.6607) 확률로 positive로 예상됩니다
# [사골국보다 더 우려먹는데 개재밌네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.6350) 확률로 positive로 예상됩니다
# [형 이제 슬슬 프로필사진 내려야 할 것 같다ㅋㅋㅋ] 는 (0.0707) 확률로 negative로 예상됩니다
# [ 에 기훈이 왜 찌찌만지놐ㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4611) 확률로 negative로 예상됩니다
# [ 거창하게 트림하고 악마드립치는거 개웃기네 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4541) 확률로 negative로 예상됩니다
# [ 킹기훈 인싸력 실화냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.7468) 확률로 positive로 예상됩니다
# [ 악마살고있대 미쳤네 ㅋㅋㅋㅋㅋㅋ] 는 (0.4313) 확률로 negative로 예상됩니다
# [ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아니 ㅈㄴ 뜸금없이 팩트를 날렼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.2505) 확률로 negative로 예상됩니다
# [ 뜬금없이 개웃기네 ㅋㅋㅋㅋ] 는 (0.0286) 확률로 negative로 예상됩니다
# [ 아 진짜 개웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.4855) 확률로 negative로 예상됩니다
# [ 뒤에서 감스트 웃는게 제일 웃기네 ㅋㅋ] 는 (0.8821) 확률로 positive로 예상됩니다
# [ 다 똑같이 생겨가지고 개웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ] 는 (0.3544) 확률로 negative로 예상됩니다

# %% [markdown]
# ## 인공신경망

# %%
# 영화 리뷰 데이터 불러오기

def read_data(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        # txt 파일의 헤더(id document label)는 제외하기
        data = data[1:]
    return data

train_data = read_data('./movie_text_data/ratings_train.txt')
test_data = read_data('./movie_text_data/ratings_test.txt')

print(len(test_data))

# %%
#토큰화

from konlpy.tag import Okt
import json
import os
from pprint import pprint


okt = Okt()

def tokenize(doc):
    # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

if os.path.isfile('./crawling_result_text/train_docs.json'):
    with open('./crawling_result_text/train_docs.json') as f:
        train_docs = json.load(f)
    with open('./crawling_result_text/test_docs.json') as f:
        test_docs = json.load(f)
else:
    train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
    test_docs = [(tokenize(row[1]), row[2]) for row in test_data]
    # JSON 파일로 저장
    with open('./crawling_result_text/train_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(train_docs, make_file, ensure_ascii=False, indent="\t")
    with open('./crawling_result_text/test_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(test_docs, make_file, ensure_ascii=False, indent="\t")

pprint(train_docs[0])

# %%
# CountVectorization
import nltk

tokens = [t for d in train_docs for t in d[0]]

text = nltk.Text(tokens, name='NMSC')
pprint(text.vocab().most_common(10))

selected_words = selected_words = [f[0] for f in text.vocab().most_common(10000)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

train_x = [term_frequency(d) for d, _ in train_docs]
test_x = [term_frequency(d) for d, _ in test_docs]
train_y = [c for _, c in train_docs]
test_y = [c for _, c in test_docs]
# Out:
# [('./Punctuation', 67778),
#  ('영화/Noun', 50818),
#  ('하다/Verb', 41209),
#  ('이/Josa', 38540),
#  ('보다/Verb', 38538),
#  ('의/Josa', 30188),
#  ('../Punctuation', 29055),
#  ('가/Josa', 26627),
#  ('에/Josa', 26468),
#  ('을/Josa', 23118)]

# %%
import numpy as np

x_train = np.asarray(train_x).astype('float32')
x_test = np.asarray(test_x).astype('float32')

y_train = np.asarray(train_y).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

model.fit(x_train, y_train, epochs=10, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 293/293 [==============================] - 165s 562ms/step - loss: 0.4521 - binary_accuracy: 0.8013
# Epoch 2/10
# 293/293 [==============================] - 21s 72ms/step - loss: 0.3181 - binary_accuracy: 0.8629
# Epoch 3/10
# 293/293 [==============================] - 14s 47ms/step - loss: 0.2924 - binary_accuracy: 0.8772
# Epoch 4/10
# 293/293 [==============================] - 8s 28ms/step - loss: 0.2703 - binary_accuracy: 0.8891
# Epoch 5/10
# 293/293 [==============================] - 8s 28ms/step - loss: 0.2552 - binary_accuracy: 0.8971
# Epoch 6/10
# 293/293 [==============================] - 8s 28ms/step - loss: 0.2365 - binary_accuracy: 0.9062
# Epoch 7/10
# 293/293 [==============================] - 8s 29ms/step - loss: 0.2130 - binary_accuracy: 0.9174
# Epoch 8/10
# 293/293 [==============================] - 8s 28ms/step - loss: 0.1945 - binary_accuracy: 0.9260
# Epoch 9/10
# 293/293 [==============================] - 8s 29ms/step - loss: 0.1766 - binary_accuracy: 0.9319
# Epoch 10/10
# 293/293 [==============================] - 8s 28ms/step - loss: 0.1603 - binary_accuracy: 0.9400
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.4011 - binary_accuracy: 0.8526

# %%
# 유튜브 댓글 데이터 확인
import re


with open('./crawling_result_text/gamst_comments.txt', mode='rt', encoding='utf-8') as f:
    strings = f.read()

strings = re.sub(pattern='[^ㄱ-ㅎ 가-힣 a-z A-Z \n]', repl='', string=strings)
comment_list = strings.split('\n')


def predict_pos_neg(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^\n".format(review, score * 100))
        return "[{}]는 {:.2f}% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^\n".format(review, score * 100)
    else:
        print("[{}]는 {:.2f}% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100))
        return "[{}]는 {:.2f}% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100)


sentiment_result = []


for comment in comment_list:
    sentiment_result.append(predict_pos_neg(comment))

with open('./crawling_result_text/comment_sentiment_ML.txt', mode='wt', encoding='utf-8') as f:
    f.write("\n".join(sentiment_result))
# Out:
# [영상 좋아요댓글 한번씩 부탁드립니다]는 96.29% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^
#
# [He is JJASTHIS]는 72.57% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [HE IS NOT CHANGMO]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [HE IS TALMO]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [He is Talmoalto]는 72.57% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [Bring rap JJASTHIS]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [ He Is gamshebellom]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [He is CODE GAMST]는 72.57% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [THISISZZASTHIS]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [ 여긴 진짜 개잘했네 ㅋㅋㅋㅋ]는 54.40% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [ he is punchline king]는 72.57% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [보여줬지]는 60.36% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^
#
# [yo]는 51.59% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [shut the fxxk a man]는 62.16% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ]는 72.22% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [느슨해진 한국힙합에 긴장감을 주는것 같다]는 83.72% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [  우결단의 인생 감스트]는 75.66% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^
#
# [